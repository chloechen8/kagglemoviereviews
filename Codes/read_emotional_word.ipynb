# %%
import os
import sys

# %%
def read_words():
    poslist = []
    neglist = []
    
    flexicon = open('SentimentLexicons/NRC_emotion_lexicon_list.txt', encoding='latin1')
    wordlines = [line.strip() for line in flexicon]
    for line in wordlines:
        if not line == '':
            items = line.split()
            for c in items:
                if items[1] == 'positive' and items[2] == '1':
                    poslist.append(items[0])
                elif items[1] == 'negative' and items[2] == '1':
                    neglist.append(items[0])
            
    return(poslist,neglist)

# %%
if __name__=='__main__':
  (poslist, neglist) = read_words()
  print ("Positive Words", len(poslist), "Negative Words", len(neglist))
  print (poslist)
  print (neglist)
# Out:
# Positive Words 3741 Negative Words 2067
# ['abandoned', 'abandoned', 'abandoned', 'abandonment', 'abandonment', 'abandonment', 'abhor', 'abhor', 'abhor', 'abhorrent', 'abhorrent', 'abhorrent', 'abolish', 'abolish', 'abolish', 'abomination', 'abomination', 'abomination', 'abuse', 'abuse', 'abuse', 'accursed', 'accursed', 'accursed', 'accusation', 'accusation', 'accusation', 'accused', 'accused', 'accused', 'accuser', 'accuser', 'accuser', 'accusing', 'accusing', 'accusing', 'actionable', 'actionable', 'actionable', 'adder', 'adder', 'adder', 'adversary', 'adversary', 'adversary', 'adverse', 'adverse', 'adverse', 'adversity', 'adversity', 'adversity', 'advocacy', 'advocacy', 'advocacy', 'affront', 'affront', 'affront', 'aftermath', 'aftermath', 'aftermath', 'aggravated', 'aggravated', 'aggravated', 'aggravating', 'aggravating', 'aggravating', 'aggravation', 'aggravation', 'aggravation', 'aggression', 'aggression', 'aggression', 'aggressive', 'aggressive', 'aggressive', 'aggressor', 'aggressor', 'aggressor', 'agitated', 'agitated', 'agitated', 'agitation', 'agitation', 'agitation', 'agony', 'agony', 'agony', 'alcoholism', 'alcoholism', 'alcoholism', 'alienate', 'alienate', 'alienate', 'alienation', 'alienation', 'alienation', 'allegation', 'allegation', 'allegation', 'altercation', 'altercation', 'altercation', 'ambush', 'ambush', 'ambush', 'anarchism', 'anarchism', 'anarchism', 'anarchist', 'anarchist', 'anarchist', 'anarchy', 'anarchy', 'anarchy', 'anathema', 'anathema', 'anathema', 'anger', 'anger', 'anger', 'angry', 'angry', 'angry', 'anguish', 'anguish', 'anguish', 'animosity', 'animosity', 'animosity', 'animus', 'animus', 'animus', 'annihilate', 'annihilate', 'annihilate', 'annihilated', 'annihilated', 'annihilated', 'annihilation', 'annihilation', 'annihilation', 'annoy', 'annoy', 'annoy', 'annoyance', 'annoyance', 'annoyance', 'annoying', 'annoying', 'annoying', 'antagonism', 'antagonism', 'antagonism', 'antagonist', 'antagonist', 'antagonist', 'antagonistic', 'antagonistic', 'antagonistic', 'antichrist', 'antichrist', 'antichrist', 'antipathy', 'antipathy', 'antipathy', 'antisocial', 'antisocial', 'antisocial', 'antithesis', 'antithesis', 'antithesis', 'anxiety', 'anxiety', 'anxiety', 'argue', 'argue', 'argue', 'argument', 'argument', 'argument', 'argumentation', 'argumentation', 'argumentation', 'arguments', 'arguments', 'arguments', 'armament', 'armament', 'armament', 'armed', 'armed', 'armed', 'arraignment', 'arraignment', 'arraignment', 'arrogant', 'arrogant', 'arrogant', 'arson', 'arson', 'arson', 'assail', 'assail', 'assail', 'assailant', 'assailant', 'assailant', 'assassin', 'assassin', 'assassin', 'assassinate', 'assassinate', 'assassinate', 'assassination', 'assassination', 'assassination', 'assault', 'assault', 'assault', 'asshole', 'asshole', 'asshole', 'atrocious', 'atrocious', 'atrocious', 'atrocity', 'atrocity', 'atrocity', 'attack', 'attack', 'attack', 'attacking', 'attacking', 'attacking', 'attorney', 'attorney', 'attorney', 'avarice', 'avarice', 'avarice', 'avenger', 'avenger', 'avenger', 'averse', 'averse', 'averse', 'aversion', 'aversion', 'aversion', 'awful', 'awful', 'awful', 'backbone', 'backbone', 'backbone', 'bad', 'bad', 'bad', 'badger', 'badger', 'badger', 'badness', 'badness', 'badness', 'bane', 'bane', 'bane', 'bang', 'bang', 'bang', 'banger', 'banger', 'banger', 'banish', 'banish', 'banish', 'banished', 'banished', 'banished', 'banishment', 'banishment', 'banishment', 'bankruptcy', 'bankruptcy', 'bankruptcy', 'banshee', 'banshee', 'banshee', 'barb', 'barb', 'barb', 'barbaric', 'barbaric', 'barbaric', 'bark', 'bark', 'bark', 'barrier', 'barrier', 'barrier', 'bastion', 'bastion', 'bastion', 'battalion', 'battalion', 'battalion', 'batter', 'batter', 'batter', 'battery', 'battery', 'battery', 'battle', 'battle', 'battle', 'battled', 'battled', 'battled', 'bayonet', 'bayonet', 'bayonet', 'bear', 'bear', 'bear', 'bearish', 'bearish', 'bearish', 'beast', 'beast', 'beast', 'beating', 'beating', 'beating', 'bee', 'bee', 'bee', 'belittle', 'be ...
# ['absolution', 'absolution', 'absolution', 'abundance', 'abundance', 'abundance', 'abundant', 'abundant', 'abundant', 'accolade', 'accolade', 'accolade', 'accompaniment', 'accompaniment', 'accompaniment', 'accomplish', 'accomplish', 'accomplish', 'accomplished', 'accomplished', 'accomplished', 'achieve', 'achieve', 'achieve', 'achievement', 'achievement', 'achievement', 'acrobat', 'acrobat', 'acrobat', 'admirable', 'admirable', 'admirable', 'admiration', 'admiration', 'admiration', 'adorable', 'adorable', 'adorable', 'adoration', 'adoration', 'adoration', 'adore', 'adore', 'adore', 'advance', 'advance', 'advance', 'advent', 'advent', 'advent', 'advocacy', 'advocacy', 'advocacy', 'aesthetics', 'aesthetics', 'aesthetics', 'affection', 'affection', 'affection', 'affluence', 'affluence', 'affluence', 'alive', 'alive', 'alive', 'allure', 'allure', 'allure', 'aloha', 'aloha', 'aloha', 'amazingly', 'amazingly', 'amazingly', 'ambition', 'ambition', 'ambition', 'amen', 'amen', 'amen', 'amicable', 'amicable', 'amicable', 'amnesty', 'amnesty', 'amnesty', 'amour', 'amour', 'amour', 'amuse', 'amuse', 'amuse', 'amused', 'amused', 'amused', 'amusement', 'amusement', 'amusement', 'amusing', 'amusing', 'amusing', 'angel', 'angel', 'angel', 'angelic', 'angelic', 'angelic', 'animated', 'animated', 'animated', 'applause', 'applause', 'applause', 'appreciation', 'appreciation', 'appreciation', 'approve', 'approve', 'approve', 'ardent', 'ardent', 'ardent', 'art', 'art', 'art', 'aspiration', 'aspiration', 'aspiration', 'aspire', 'aspire', 'aspire', 'aspiring', 'aspiring', 'aspiring', 'astonishment', 'astonishment', 'astonishment', 'atone', 'atone', 'atone', 'auspicious', 'auspicious', 'auspicious', 'authentic', 'authentic', 'authentic', 'award', 'award', 'award', 'baby', 'baby', 'baby', 'balm', 'balm', 'balm', 'banquet', 'banquet', 'banquet', 'baptismal', 'baptismal', 'baptismal', 'basketball', 'basketball', 'basketball', 'beach', 'beach', 'beach', 'beam', 'beam', 'beam', 'beaming', 'beaming', 'beaming', 'beautification', 'beautification', 'beautification', 'beautiful', 'beautiful', 'beautiful', 'beautify', 'beautify', 'beautify', 'beauty', 'beauty', 'beauty', 'beer', 'beer', 'beer', 'befriend', 'befriend', 'befriend', 'benevolence', 'benevolence', 'benevolence', 'benign', 'benign', 'benign', 'betrothed', 'betrothed', 'betrothed', 'birth', 'birth', 'birth', 'birthday', 'birthday', 'birthday', 'bless', 'bless', 'bless', 'blessed', 'blessed', 'blessed', 'blessing', 'blessing', 'blessing', 'blessings', 'blessings', 'blessings', 'bliss', 'bliss', 'bliss', 'blissful', 'blissful', 'blissful', 'bloom', 'bloom', 'bloom', 'blossom', 'blossom', 'blossom', 'boisterous', 'boisterous', 'boisterous', 'bonanza', 'bonanza', 'bonanza', 'bonus', 'bonus', 'bonus', 'bountiful', 'bountiful', 'bountiful', 'bounty', 'bounty', 'bounty', 'bouquet', 'bouquet', 'bouquet', 'bridal', 'bridal', 'bridal', 'bride', 'bride', 'bride', 'bridegroom', 'bridegroom', 'bridegroom', 'bridesmaid', 'bridesmaid', 'bridesmaid', 'brighten', 'brighten', 'brighten', 'brilliant', 'brilliant', 'brilliant', 'brotherly', 'brotherly', 'brotherly', 'buddy', 'buddy', 'buddy', 'buss', 'buss', 'buss', 'calf', 'calf', 'calf', 'candid', 'candid', 'candid', 'captivate', 'captivate', 'captivate', 'carol', 'carol', 'carol', 'cash', 'cash', 'cash', 'cathedral', 'cathedral', 'cathedral', 'celebrated', 'celebrated', 'celebrated', 'celebrating', 'celebrating', 'celebrating', 'celebration', 'celebration', 'celebration', 'celebrity', 'celebrity', 'celebrity', 'celestial', 'celestial', 'celestial', 'ceremony', 'ceremony', 'ceremony', 'champion', 'champion', 'champion', 'chant', 'chant', 'chant', 'charitable', 'charitable', 'charitable', 'charity', 'charity', 'charity', 'charmed', 'charmed', 'charmed', 'cheer', 'cheer', 'cheer', 'cheerful', 'cheerful', 'cheerful', 'cheerfulness', 'cheerfulness', 'cheerfulness', 'cheering', 'cheering', 'cheering', 'cheery', 'cheery', 'cheery', 'cherish', 'cherish', 'cherish', 'child',  ...
